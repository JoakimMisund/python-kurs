# %% [markdown]
# # Python 2023

# %% [markdown]
# # Oversikt del 1
#
# 1. Kurs intro
# 2. Typer og variabler
# 3. Syntax
# 4. Exceptions
# 5. Kontrollflyt
# 6. Funksjoner og Klasser
# 7. Scripting og Argumenter
# 8. Import og moduler
# 9. Filhåndtering
# 10. Nettverk

# %% [markdown]
# ## 1 - Kurs intro

# %% [markdown]
# ## 1.1 Python

# %% [markdown]
# * General-purpose programming language
# * Egner seg veldig god til script
#  * Men kan også brukes til mer komplekse program
# * Nyeste versjon er 3.11
#  * Python 2 (2.7) *endelig* utgått og støttes ikke lenger

# %% [markdown]
# ## 1.2 Hvordan bruke Python
#
# Tre vanlige metoder:
# - python shell
# - python fra kommandolinjen
# - skript i .py-fil

# %% [markdown]
# ```
# watcher@apollo:~$ python
# >>> print('Hello world')
# Hello world
# >>>
# ```

# %% [markdown]
# ```
# watcher@apollo:~$ python –c "print('Hello world')"
# Hello world
# watcher@apollo:~$
# ```

# %% [markdown]
# * Python script lagres i filer med .py ending
# * og kjøres i cmd med:
# ```
# python script.py
# ```

# %% [markdown]
# ## ...pluss et par til
#
# - Ipython/Jupyter, gjerne som notebook
# - IDE (f.eks. PyCharm eller WingIDE)

# %%
print('Hello' + ' ' + ' magnus!')
print('Interactive shell for the win!')

# %% [markdown]
# ## 1.3 Oppgaver

# %% [markdown]
# * Hvis dere ikke har gjort det allerede:
#  * Last ned og installer Python 3.11 fra python.org
# * Åpne cmd og skriv "python"
# * Verifiser at den sier "Python 3.11.x ..."
# * Skriv:
# ```python
# print('Hello world')
# ```
# * For å avslutte Python, skriv *exit()*
# * Lag en fil *mitt_script.py* hvor du skriver inn koden over (bruk notepad.exe, Notepad++ eller en annen text-editor)
# * Kjør scriptet i cmd med:
# ```
# python mitt_script.py
# ```

# %% [markdown]
# ## Oppgaver (2)

# %% [markdown]
# * (I cmd) naviger til mappen dere fikk av oss
# * Kjøre kommandoene:
# ```
# pip install -r requirements.txt
# ```
# ```
# jupyter lab
# ```
